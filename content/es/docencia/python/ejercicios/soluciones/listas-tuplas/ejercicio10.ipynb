# %% [markdown]
# <a href="https://colab.research.google.com/github/1900881044-m/-ESTRUCTURA-DE-DATOS-E-/blob/main/content/es/docencia/python/ejercicios/soluciones/listas-tuplas/ejercicio10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que almacene en una lista los siguientes precios, 50, 75, 46, 22, 80, 65, 8, y muestre por pantalla el menor y el mayor de los precios.

# %% [markdown]
# ## Solución

# %%
prices = [50, 75, 46, 22, 80, 65, 8]
min = max = prices[0]
for price in prices:
    if price < min:
        min = price
    elif price > max:
        max = price
print("El mínimo es " + str(min))
print("El máximo es " + str(max))
# Lista de precios
prices = [50, 75, 46, 22, 80, 65, 8]

# Inicializar menor y mayor con el primer valor de la lista
menor = prices[0]
mayor = prices[0]

# Recorrer la lista para encontrar el menor y el mayor
for price in prices:
    if price < menor:
        menor = price
    elif price > mayor:
        mayor = price

# Mostrar resultados
print("El mínimo es:", menor)
print("El máximo es:", mayor)
# Out:
# El mínimo es 8
# El máximo es 80
# El mínimo es: 8
# El máximo es: 80
