# %% [markdown]
# <a href="https://colab.research.google.com/github/1900881044-m/-ESTRUCTURA-DE-DATOS-E-/blob/main/content/es/docencia/python/ejercicios/soluciones/listas-tuplas/ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que almacene las asignaturas de un curso (por ejemplo Matemáticas, Física, Química, Historia y Lengua) en una lista y la muestre por pantalla.

# %% [markdown]
# ## Solución

# %%
subjects = ["Matemáticas", "Física", "Química", "Historia", "Lengua"]
print(subjects)
# Crear una lista con las asignaturas del curso
asignaturas = ["Matemáticas", "Física", "Química", "Historia", "Lengua"]

# Mostrar las asignaturas por pantalla
print("Las asignaturas del curso son:")
for materia in asignaturas:
    print(materia)
# Out:
# ['Matemáticas', 'Física', 'Química', 'Historia', 'Lengua']
# Las asignaturas del curso son:
# Matemáticas
# Física
# Química
# Historia
# Lengua
