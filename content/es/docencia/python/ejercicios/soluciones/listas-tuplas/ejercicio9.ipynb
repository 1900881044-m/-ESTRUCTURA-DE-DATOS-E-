# %% [markdown]
# <a href="https://colab.research.google.com/github/1900881044-m/-ESTRUCTURA-DE-DATOS-E-/blob/main/content/es/docencia/python/ejercicios/soluciones/listas-tuplas/ejercicio9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que pida al usuario una palabra y muestre por pantalla el número de veces que contiene cada vocal.

# %% [markdown]
# ## Solución

# %%
word = input("Introduce una palabra: ")
vocals = ['a', 'e', 'i', 'o', 'u']
for vocal in vocals:
    times = 0
    for letter in word:
        if letter == vocal:
            times += 1
    print("La vocal " + vocal + " aparece " + str(times) + " veces")
    palabra = input("Introduce una palabra: ").lower()
vocales = "aeiou"
print(f"\nPalabra: {palabra}")
for vocal in vocales:
    print(f"{vocal}: {palabra.count(vocal)}")
# Out:
# Introduce una palabra: o
# La vocal a aparece 0 veces
# Introduce una palabra: i
# La vocal e aparece 0 veces
# Introduce una palabra: e
# La vocal i aparece 0 veces
