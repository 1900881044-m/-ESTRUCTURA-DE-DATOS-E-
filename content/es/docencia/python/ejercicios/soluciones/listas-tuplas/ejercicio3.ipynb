# %% [markdown]
# <a href="https://colab.research.google.com/github/1900881044-m/-ESTRUCTURA-DE-DATOS-E-/blob/main/content/es/docencia/python/ejercicios/soluciones/listas-tuplas/ejercicio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que almacene las asignaturas de un curso (por ejemplo Matemáticas, Física, Química, Historia y Lengua) en una lista y la muestre por pantalla.

# %% [markdown]
# ## Solución

# %%
subjects = ["Matemáticas", "Física", "Química", "Historia", "Lengua"]
scores = []
for subject in subjects:
    score = input("¿Qué nota has sacado en " + subject + "?")
    scores.append(score)
for i in range(len(subjects)):
    print("En " + subjects[i] + " has sacado " + scores[i])
    # Lista de asignaturas del curso
asignaturas = ["Matemáticas", "Física", "Química", "Historia", "Lengua"]

# Mostrar las asignaturas por pantalla
print("Las asignaturas del curso son:")
for asignatura in asignaturas:
    print(asignatura)
# Out:
# ¿Qué nota has sacado en Matemáticas?7
# ¿Qué nota has sacado en Física?7
# ¿Qué nota has sacado en Química?4
# ¿Qué nota has sacado en Historia?6
# ¿Qué nota has sacado en Lengua?5
# En Matemáticas has sacado 7
# En Física has sacado 7
# En Química has sacado 4
# En Historia has sacado 6
# En Lengua has sacado 5
# Las asignaturas del curso son:
# Matemáticas
# Física
# Química
# Historia
# Lengua
